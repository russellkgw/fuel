# %%
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib import rnn  # rnn stuff temporarily in contrib, moving back to code in TF 1.1
import os
import time
import math
import numpy as np
import my_txtutils as txt
import sys

tf.set_random_seed(0)
tf.reset_default_graph()

SEQLEN = 30
BATCHSIZE = 20
ALPHABETSIZE = txt.ALPHASIZE
INTERNALSIZE = 128
NLAYERS = 3


keep_prob = 0.8    # some dropout


# Load Shakespeare Data
shakedir = "shakespeare/*.txt"
codetext, valitext, bookranges = txt.read_data_files(shakedir, validation=True)

# display some stats on the data
epoch_size = len(codetext) // (BATCHSIZE * SEQLEN)
txt.print_data_stats(len(codetext), len(valitext), epoch_size)

# DEFINE PLACEHOLDERS
keep_prob_placeholder = tf.placeholder(tf.float32, name='keep_prob')  # dropout parameter
batchsize = tf.placeholder(tf.int32, name='batchsize')


# inputs
X = tf.placeholder(tf.uint8, [None, None], name='X')    # [ BATCHSIZE, SEQLEN ]
Xo = tf.one_hot(X, ALPHABETSIZE, 1.0, 0.0)                 # [ BATCHSIZE, SEQLEN, ALPHASIZE ]

# expected outputs = same sequence shifted by 1 since we are trying to predict the next character
Y_ = tf.placeholder(tf.uint8, [None, None], name='Y_')  # [ BATCHSIZE, SEQLEN ]
Yo_ = tf.one_hot(Y_, ALPHABETSIZE, 1.0, 0.0)               # [ BATCHSIZE, SEQLEN, ALPHASIZE ]

# input state
Hin = tf.placeholder(tf.float32, [None, INTERNALSIZE*NLAYERS], name='Hin')  # [ BATCHSIZE, INTERNALSIZE * NLAYERS]

# using NLAYERS layers of GRU cells, unrolled SEQLEN=30 times
# dynamic_rnn infers SEQLEN from the size of the inputs Xo

cells = [rnn.GRUCell(INTERNALSIZE) for _ in range(NLAYERS)]

# "naive dropout" implementation
dropcells = [rnn.DropoutWrapper(cell,input_keep_prob=keep_prob_placeholder) for cell in cells]
multicell = rnn.MultiRNNCell(dropcells, state_is_tuple=False)
multicell = rnn.DropoutWrapper(multicell, output_keep_prob=keep_prob_placeholder)  # dropout for the softmax layer

Yr, H = tf.nn.dynamic_rnn(multicell, Xo, dtype=tf.float32, initial_state=Hin)
# Yr: [ BATCHSIZE, SEQLEN, INTERNALSIZE ]
# H:  [ BATCHSIZE, INTERNALSIZE*NLAYERS ] # this is the last state in the sequence


# Softmax layer implementation:
# Flatten the first two dimension of the output [ BATCHSIZE, SEQLEN, ALPHASIZE ] => [ BATCHSIZE x SEQLEN, ALPHASIZE ]
# then apply softmax layer. This way, the weights and biases are shared across unrolled time steps.

W = tf.Variable(tf.random_normal([INTERNALSIZE, ALPHABETSIZE]))
B = tf.Variable(tf.random_normal([ALPHABETSIZE]))

Yflat = tf.reshape(Yr, [-1, INTERNALSIZE])    # [ BATCHSIZE x SEQLEN, INTERNALSIZE ]
Ylogits = tf.matmul(Yflat, W) + B     # [ BATCHSIZE x SEQLEN, ALPHASIZE ]

Yflat_ = tf.reshape(Yo_, [-1, ALPHABETSIZE])     # [ BATCHSIZE x SEQLEN, ALPHASIZE ]

loss = tf.nn.softmax_cross_entropy_with_logits(logits=Ylogits, labels=Yflat_)  # [ BATCHSIZE x SEQLEN ]
loss = tf.reshape(loss, [batchsize, -1])      # [ BATCHSIZE, SEQLEN ]

Yo = tf.nn.softmax(Ylogits, name='Yo')        # [ BATCHSIZE x SEQLEN, ALPHASIZE ]
Y = tf.argmax(Yo, 1)                          # [ BATCHSIZE x SEQLEN ]
Y = tf.reshape(Y, [batchsize, -1], name="Y")  # [ BATCHSIZE, SEQLEN ]

train_step = tf.train.AdamOptimizer(0.001).minimize(loss)

# stats for display
seqloss = tf.reduce_mean(loss, 1)
batchloss = tf.reduce_mean(seqloss)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y_, tf.cast(Y, tf.uint8)), tf.float32))

# for display: init the progress bar
DISPLAY_FREQ = 50
_50_BATCHES = DISPLAY_FREQ * BATCHSIZE * SEQLEN
progress = txt.Progress(DISPLAY_FREQ, size=111+2, msg="Training on next "+str(DISPLAY_FREQ)+" batches")

# init
istate = np.zeros([BATCHSIZE, INTERNALSIZE*NLAYERS])  # initial zero input state
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
step = 0

# training loop
for x, y_, epoch in txt.rnn_minibatch_sequencer(codetext, BATCHSIZE, SEQLEN, nb_epochs=2):

    # train on one minibatch
    feed_dict = {X: x, Y_: y_, Hin: istate, keep_prob_placeholder: keep_prob, batchsize: BATCHSIZE}
    _, y, ostate = sess.run([train_step, Y, H], feed_dict=feed_dict)

    # display a short text generated with the current weights and biases (every 150 batches)
    if step // 3 % _50_BATCHES == 0:
        print()
        print("Generating some random text...")
        
        ry = np.array([[txt.convert_from_alphabet(ord("K"))]])
        rh = np.zeros([1, INTERNALSIZE * NLAYERS])

        for k in range(1000):
            ryo, rh = sess.run([Yo, H], feed_dict={X: ry, keep_prob_placeholder: 1.0, Hin: rh, batchsize: 1})
            rc = txt.sample_from_probabilities(ryo, topn=10 if epoch <= 1 else 2)
            sys.stdout.write(chr(txt.convert_to_alphabet(rc)))
            ry = np.array([[rc]])

        print()
        print("FINISHED GENERATING RANDOM TEXT")
        print()

    # display progress bar
    progress.step(reset=step % _50_BATCHES == 0)

    # loop state around
    istate = ostate
    step += BATCHSIZE * SEQLEN
    
print()
print("-----FINISHED TRAINING-----")
# Out:
# Loading file shakespeare/merchantofvenice.txt
# Loading file shakespeare/loverscomplaint.txt
# Loading file shakespeare/othello.txt
# Loading file shakespeare/hamlet.txt
# Loading file shakespeare/kingjohn.txt
# Loading file shakespeare/various.txt
# Loading file shakespeare/sonnets.txt
# Loading file shakespeare/asyoulikeit.txt
# Loading file shakespeare/titusandronicus.txt
# Loading file shakespeare/2kinghenryvi.txt
# Training text size is 0.9178218841552734MB with 149.2587890625KB set aside for validation. There will be 1604 batches per epoch
#
# Generating some random text...
# p?%^.C.?(HNNACF0NFm^b,],C]C]^b,(0^^^(d^^Ap%C.*?>dpp%p]V0FhC^pC%hH^^AAAA%^^4^A^C^A?AC^^HAAN.AC^.xC-C]A0CFm0C^AK?.^NCA.CA0]AC%?^hA^^pNAC?AC]%0A%AAC?^AA?^K^.AC^CKmACAC?%H.^AC?^AH^^?^^A%AA^^A?%.NH^AAADDA(.(C%.AA0DA%.XA%(%pCCA]?%^K?^pAK^HNmp^4A.0>^d?C^>?.ADH^NZA^^N4p^ZNC0^pNm^F0N0b^^Z^NC.^bx-0pFFh^0?AK^m^^mmd^pd.^>C0
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# QE DESELICNEN	O	Hwa hel st melstee.
#
#
# TSSLAND	The trees te st sirs ais int ie the te o hasine ood themy th ane whandy hir ar dr itl yutur to w ather hiner
#
# 	Asestio nt lithe lo so hougiorer mpent y lirs ir h le met ha hoselll ar dourserof tunging ine thow aly my to d hu bithe noro ded the amy ure, arlorimplilily ofavering tith the thint tre wandot, snad.
#
# AREDIDO	C se cithing lascranc het
# y I whe mndis, she a lor wnoweled, ou tarne whttre hine
# 	I may, tulde heenelor sart ied, Ifr ain g o d tiof laseathe
# 	Whis lorthe the heald toom,
# 	I hothil hu pattaseer ime mary hatho metioth, bue at higranor,
# 	nol satd, I dese
# 	Ther on theer an t are werd
# 	sa y omerayoun be the herr hen on then wnel m my stor he lly so tron seice, bye worea
# hitesouce hy d moue anes ie thelen thend os ite mo his he lild tine she disthe ieng se bed thes isen, ta ter thers,
# 	Hour auren sure she llive an the witho h it hicer feerrsor sif moserthardifou he iten, the merele
# 	Oousera byos an hin, be that ine, had tol nor th
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# QBENDENET	NRDE	No a my t om thang thing, Iarissond pardy,athere teend, hou hatheere ire, mealy stered
#
# SAST	A d the thot ene prsckickies witlet theu terascroun woris
#
# 	Mene th mu l ay hous seredris, ane, matl nowe the s sthome terrethird s lime fares tange.
#
# OT	Whon arstour, all be tith atheroutiso hounce in har dot th me pothane bleto see,
# 	hes be het tsus s as aucamert inte is min shomearthou bostieth ha ghotorsse
# 	To he dim yore ing ihet o a astrotare tult hengongrtigot morthe wave timensthol the paved
#
# 	To ase betharet tay ho bud by ma glon foresour t sard murantht a im th toman there
# 	[ote picked, t theed fofe toom in my ur thar sotretien,
# 	[n tu be sitle tres mer,r se tit e fold tofrand forim.
# 	Wiet, ther fath all thak irs and ot thar wntent
# 	Anothy mamishime baryo anit mu sofr,
# 	he thead fof mule thesthe lf te tor he tetr ise tre am,
# 	Whou le mfoo hart, hovendes thers be ay sick, auts tuee
# 	he wime tof the mr spakkngothithe brownet
# 	Ored hat  aus ose tordilig tow teror heee se c
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ENTRCO	Non, lats on iot,
# 	Ars wall hel weath thetree, the soret,
# 	An tht al ots surctrenst inis bte tons fe coune shrs mentty soud oncetere athther speres, anden tyou st an toon tood me aithas my uro belyond teandes, aht hinghise tayelof me tienou,
# 	[aiencoum you w l th th hire tss on hire weald bend,
# h ur th n tsoue is wislyou s ot as ie ts, toouth se ancall aye if that tht ance ince sint in ind thes ine thans on the ty ll me ther home nonave coseseands hatlonodeestir sest f an ane am yome theune, bouct
#
# AMy t me lith n you sates my, bnead,
# 	Wit er tet te co llea th net ie fill no thas austh hyushrot bulade an ave asd thas wersions,
#
# ht cincheen aloud an tor, tolealed st l at seraloffoof, the tascant yee ay love, thimantsilenstillas on woll mest fill songantteand thearald,
# The tay hant her and oos w a deat e at s and men as tate inct l she ite no l te the hime arelie.
#
# ASIO	Or an tome asithy buls and it oerdsot, f ror toud tullof in arofren our and stont he ile and bridedin beath w ar
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# 	So me seestife, sod ailieg.
#
# STING IAGre dime ooser on midsed;
# 	So suen tale is the tosde dy butied soust
#  ftir dave h at too hou are ard in loree
#
# 	[nee nenteres a donee oom by moun will my ther ard byowest
# 	Ween youg ndo soretie io laken to deres shee,
# 	Hes tasules an he sear a me blick nathings, sne heathese, hater wortomer oo sutlen and a by lery.
#
#
# MEMSTIAN O CLLDIV.
# NSCENS	S And I han dero tat if soue her, go ser ass done thieg all men sa ch n the s matharesord
#  on herate net whrul shou, fort esprances ther of ies o toor sa thend o dore mpll c
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ip. Frind shy wo sene.
#
# TIII S	A ldsert iods thortseed se lowe,
# 	And ware menty to huth sersine
# 	Ty word him, ihit son what iuntale,
# 	This ar the the allot mongred fouthr har shis ouesthong asdss
# 	Becie onse, a led at dinke to cimpous and at tat inela goud, of morene ho eed hosh sedrt
# 	I to din w mr thee hom nowhingeen wand.
#
#
# KSNENIO 	Se  t  a lit onield th he the and, Itanteris at sedree.
#
# OSILA	IA, hit sis cos chathand hir sp aren, wo d is thesim cotrast iselis mo thts otens and bits theele fein and in thes if theser oun,
# 	[iie none, arst le ielir you thees.
# 	Hase sicusur dimer thes healfe thiu wett
# 	Who sired this thel wrist herad brongon sat in that tomeselofe as hemait asdames se som,
# 	Tay of asther amy.
# 	[Ritene he hat onty are spppoushe hevingstest ou hermodrthied and sand son, thethot
# 	A disien my love;
# 	Tinst wellomad his hond. Are te must, thin arthor theall
#
# 	Andis the ceadre hichispat sherdsse
# 	A caustayo muceaice,
# 	Frone of th t us mante werste aithin.
# 	And is sim iastee
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# I
# 	Him mathe of lo me toundete sand otise ondes
# 	Tous he the faitt is and so sioureathystre te loove.
#
#
# CHELLI	So late t a dou fro lear,
# 	Whan wat so art mn of and sit een or sher.
# 	O ane this war  a d mpre whel,
# 	And bongows the deather wath of tie alt art to mis se
#
#
# LUCUSS]O,A	Wrono, traliou teat he mears ie fout he hais hon
# 	O, wont ho mise art and yom losd,
# AMLIUS	I munt mise siall fol in sestiod muthice thathing.
#
#
# THERTHAMOTAONO ON tht enomerind a coued; so dou her in the a tho e and this oom fishit,
# 	he aldoun he sas histare.
# 	To this siettatsiof sha sount, thunchon aid;
# 	A desitill am  ie suthere a bare bland mis tr saiel ay the, Iudas iolle his, and tor my hand.
# 	The  is bsancis a he mone this ience meter
# 	Hores am thondel be oush ar of searit yeuld,
# 	That our is of to thay owhy to the to loug bar altons, af mese so sead med,
# 	Andere of t ais shongat, be testro m noor,
# 	Heranous thats hat what have th then fot samprsais sand husd,
# 	With sour the monds to forime framet tong de
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ing ant ir te latrt.
#
# 	[Hant an  a  ta the thot.
#
# AGO	Aod to mulle to thay oee.
#
# ROSELITAn sery tho tisut fereng it beaverst fors not and is it in oon a land
# 	Ferear the teame ing hes buth
# 	IA	my bore, wrld the troure tene the tas nteerase nove o tone tretie, I at to thone mat hels andowee
# 	Art se thim tampse, the aiterould non th thouet nourt
# 	What to to sarlesill is antlis, and soet mustarithen thethie surn himeas,
# 	Thee, whor tirt thit it the siree thom tuld menteer for, ou doullat
#  tot mot eat in berid thar.
#
# LACATIUS	You as oot thethen halt witt st all thow th whu tut if the erind.
# 	I shir more monce toment ie onind oofere tood this wort o thon hell, ton tue whereanin were.
#
# But I look to chourt tige on mast
# 	The tore be suend thost hate iner, of the alif to nothtorse
#
#
#
# SATUE Noon a hightt andenoot
# 	O, s cam brade boringit,
# Bun hown it se me iet in the have that than thaikedown,
# 	To tirese tho lot atore, and yor foor in audsh to thit is hearss,
#
# I t ep ther hitlenon mure, thos th
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# EN	I at all dy to sealld thee say on thome.
#
# 	Sowhe tigttire, mf thon darnee oou tuel ow ays
# Ntrad in st mord dhadd separed a do hond meshot tad tainge
# 	To staseds aid bearare fertearear ig asten all be onest of that; thy blothe
# 	And der my arin to the spit tllle.
#
# 	BESSant he, myowouhe hunstins or andaserth,
# 	Sonl me herrett deenetinim, yod duch me cay taithot hore,
# 	I'll shale me thas stirld as a courth,
# 	And bloor weat the dow hisprasit ded ayldown to thou tronge.
#
#
# OROCLDO	Hes wenth wotren you trungionsend
# 	A demilith yat wereste arlise mystel ond the how
# 	to lete to thon ondser ing, I so do dound beer on her sel caindino
# ; hid with spto nye sirsse fored nsedortire to shackingid, ane to mingat d y ut me and hantised and d sow, the tond.
#
# 	[Ente  ES ONCE	Con o thime
# 	Whed se w le hom, th n tor hit hat stied your wit.
#
# HAMTERIU
# 	She, lingt in my louct my andingess on tue, shangavedise, a manest se wild.
#
# AAGO	I am s ome well andinente hin bratith wowing at to lime in,
# 	I hed de a dow
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ENT GE	IUS]
#
# HYLLTO	Hise in thir flecctarn hathath, hevens,
# 	Hele brow on and sofly sushine
# 	With lis ie meat selis fer well wath
#  thes ing in ars itiroms hear sas, in thes of fro sir.
#
# COLION wras ie thang ale hour oursely that ancos. wo hall,
# 	Wo the sto the had bies teit, this hell.
#
# 	Ang ana muse his se ant than stake and a my thre.
# 	Sild d s or fir the min, ot spesse ffe tor the
#
# SANID	Pe anden ame bld migl the hisesaild and meathis of crusct,
# 	That m so su my brin, wn tir, it that sor moull whent of ineard ot wes icut,
# 	As and on the ffotred
# 	Tull soon is hot st is therso mign all,
# 	And ba nor forr is amander somes it
# 	shale, mp and ire, fottters ane fre mishims,
# 	Thee bly fith rou aishar my, with liks aneer mak ss the, hat ort as phout
#
# 	O asthin if bringsthar and have io, ard bout,
# 	The as ne she ants is will, sistan ty with
# 	To de as ooffom hertelfea by wist as barne hive nour ant oreer.
# BRASAILA	Dod, thou here the then spees so tere whore mane in athe shrand
# 	Ale well drspats
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# imy was nout d me love sale dit, in ter thine onith
# 	Shourd aienorien theree be are byod spar y me on my lite; ond hy to but
# 	thal hed to so have our his atl nas simpots:
# 	Thy long of wo lise tit, thet beth ties
# 	An istuethr mint is maye ay.
#
# DOSSLLON	 yed my, on in ay. I so ligl bre be to natir.
#
# 	Hids ithel and teter all dite al a d am thin doonse steard itseent
# 	That so thill him as sher thot mose,
# 	I silldingall shoul, shise by sod, the till norse wnst,
# 	With sa e on aildinot weld wnady hirts thougs thou anded
# 	Th th me sull dust my lank som to wing
# 	Herrsed thule to to a piret bentare:
# 	Whis dimeldetare barite maye that a tole to ther,
# 	That,
# 	[And sir an wo her oo  one this that
#
#
# ALETO	A hordaind thiestare, so ded m t leverth
# 	Sart, tro msaing drie,
# 	Hes it hare tame ieer, wo hise be coot
# 	To bucl to dist heen his de anss
# 	Bet ints an st eens we lakn arane,
# 	As ol my it to hid to ang it, the thar dond mind.
#
# HARLONERNSR	Thath my horr ans tran otreir,
# 	Selort, hild then tore must
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ed on soutly bosck, ard no hers and.
#
#
# PHELIA	O,
# Hom shat whom siasthresthat buttoss oetrencoor
# 	And nothis tames, be came on troult
#  ir mat thuch aflar your soour stind
# 	Ar ar taise,
# How thou moddore to lith, selins and tilly sum. That meltone
# 	Thim
#
# 	Incm saniese, bet of hith all mo ner ofathty bur sand ame of heath,
# 	Ao nate wave weethict,ren you to eet theld of ance,	The porith aldelf to be my;
# 	And in, woulf macee the toll, you ham,
# 	Ar now thous tr m me that he mer the hir havile
# 	Whim failes, this presid digherild
# 	With o hy fisthre fom her ser ands and in mestren of treee,
# 	He fich as tilert breer, weel sheer,-well will then,
# 	An will sould bt ithin.
#
#
# HAELATO	How on sethat, tham mo toute sorly steans well,
#
# 	Astrnst on oust forre s anlles yous tooth the mome;
# 	O feten thour shat buald, asd thy werre
# 	And tot, borthand.
# 	Hamatr to love mit mead on is berath, oofeth the hord hit and theake hell he lls.
# 	Ays are sulis so as and the meted.
#
# TATIO	Hord by shy ther hod arat yo notl
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# E shan  it sholl he have whoulfor and thate
#
# HANCELIO, sa  auctiol,
# 	Toulait, ant are wood the to trico st st thou for ded.
#
# THALLE	To what the shemoth art on it yee timn whe serace tht soof som.
# 	The hevintt your has the chis shascead, and hearthinds hrut, inch to bed ir my tore,
# 	Of stamo lime, will tree mand he my teare sall thanthon yours and the
# 	The highe ie and beeth, lensile a dever bee sore swell
# BAS, And what that thes wo gave tee an ie wheat on tosstres ane, it it heresearter
#
#
# Tis mistio tingun the tar bise houts that.
#
# ONICUS	On she, way in yicu to love thich.
# TRUSDEMONATO Non ame wish ash, in st a  this she tous, the center htarll her suce of some tonest
#
# 	[Mentitt the my sang of whall, in loor de ast inkel ais thir hadle tontad our hinter hold aire
#
#
# OTHELLO	Wey toe  a  ham the with athe sou hell hin shen will, wees, ong mands this hear oot by mes,
# 	The beres ined, the seere to the preat,
# 	To that to helsstar hay sples,
# 	The will me clove wntis sele. Th ms is whend, the
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# EN, ANITIA	As than y ur prathen are of my and tain.
#
# ATICTION	Whis ber the beestaner thy th t ho tl thes oft
# 	treigaick a sifule frinst
# 	The fartalf then hor mee ase bet ham,
# And wins on my lighe
# 	To hor a saie des, mantre sill be thoushtand, bo fore surd itere me beed
# 	Wath me ay allige thou stromans
# 	The arof is ancery; in touthy mect,
# 	Wean shim answeld herencknaw
# An serd it weer whould withild,
# 	Ther fot the mune, a peresealf this and brentes of har me
# I
# 	Wee  art mer o  thouth loshat shesthrensed wookssithor:
# 	I dane. ard what my
# mls tor of eir hou bandsther that of is the print that a prors.
#
# 	[Excule
#  GORDIO	G a  mush he worl, sich it sings.
#
# 	[Exett I thase tory
# 	And me as ald stow and
# 	Her these suade im.  in sien
# 	And mutting hotion amano to weat star thethastad fing: fow lown.
#
# LAUDETIA	Tere sere bearitiers, brot in trons,
# 	That te serenart, I thang ne bets wo low he word,
# 	Ht eng trece trout ou so but sear.
#
# 	As my with
# 	here her bene tue mistout a solay
# 	All thin sor this
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ENG JORN	Det hent on thentest one.
#
# O mEND	A wind anct shauntlak, the tignteese
# 	I dave as isions hove
# 	And baighos som me are bhes that dusast.
# 	The moresit, whit hair foll not he mend;
# 	Iane morest hast too the bensang thin s miss ateds hat
# 	Will nicle wive herte mee that hempord yet would.
# 	Heve camte is han and bet ser le his de sere wer
# 	And is fore the wind mangs an a bilesiong; and they to himl,
# 	So dut to dustrand blets wealo so thour have a dinkis man
# 	I to be dastestrush,
# 	Whine ton sit then ford a lest surcknot sisprot
#
# 	Iall wowh must bairsted of to moranco los to so lots and to
#
# The sour a well sout ourts my hearen whtld thir toons to cum
#
#
# Whiming of me toress. All meathin and.
#
# Of whel shespllod mine she bs and a mad ng bre ain tre sely;
# 	A d shing, a suco feamir th chands.
#
# TINTUN	A dow, lort sire is the housh a dear ampers se
# 	Whace of saing shard by ander hre die
#
#
# HOMLANI'
# 	O pard no dor hos midlo to wouh surld,
# 	Hell be mite well with if bont the and meat ang searty
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# NI toow hise and
# 	Ath sorstom, is his it seray an boud
# 	On mall hemes fars,
# 	I'ts tlot his haish not tigh wles
# 	Wears, and, itsit watiom.
#
# 	[Entlit,
# SAUDEMILIA	To loue seeated.
#
# Tir how de st nied, and will him: ffrear woss fatere.'
# 	To while sas mises alaith ou strous,
# 	Tho ses wern in tha dent thas had say mark a shale sers,
# 	And for to hast,
# 	These pleere on may sor to thrspood,
# 	The foills or and at to the hise head:
# 	Thest for ane ore beate, sea hid hor sweet
# 	Mom she, hat hire hild my a sus,
#
# 	Thou bunte tran of in trou sor sto les doneathin.
#
# OTHILO	I womlordst as ie theestoun, his with the dint,
# 	Sterist, aus a poosat, soofen ture bood mond shall,
# 	Thickss he swing highe to serid wome thy suctar fam
# 	That whathink asmamy,
# 	Tall.
# 	O, my live hast heam hents ot.
#
# OTHELIA	A m s ledre sit, treat and ald aid which hive,
#
#
# TAELE	We tul with th the frete on shish il as mere an ameshice
# 	Wo my stull,
# 	And and mast, herter ane beraise, an in of hivelom how daman to mer
# 	I partill so hou
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ]
#
# 	MARTONUS NTRIANARCUS ANG LORNUS IN GORCANDUS	And tition worth
# 	And that have such thin iftere the ar ie
#
# Hose on you dimertighoning;
# 	Andll fore night str gattan to him thet to de aime;
# TARDESIAGO And, I heavint m s in hind of a  s me hell wisen
# 	Tare it mrouss an oo my the sere wher then, bray, andee alaine.
#
# Of ILIA	Oo loth nor and than thery duce o d mott torowas
# 	Than the mace: your and whind mat ee derine.
#
# MARUNER	Ther me to ds alasing seed an at you h re that aig sie
# 	That as a  ne hale by hard, and alith is theen and bild the therre.
# 	An  he murl no mothere treie,
# 	Bistow it at ofrunt buch not and is a did.
#
# BASAANDR	Nor so, sumpitailige me firtere.
#
# Best thou to she hall the entre she l to nothin mishe angerof
# 	Or me a moren they thes se lave;
# And brunt to me he me, have to mome sille
# 	Ou tem tt this me icking my luad bo dy faten
# 	And ie in ser in thin whond tane and atie teace ant,
# 	Tomprowh, shind the thy meadine, hisd in thiss no the prord; and ane to clesanth thy gant
#
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# ==================
# -----FINISHED TRAINING-----
