# %%
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib import rnn  # rnn stuff temporarily in contrib, moving back to code in TF 1.1
import os
import time
import math
import numpy as np
import my_txtutils as txt
import sys

tf.set_random_seed(0)
tf.reset_default_graph()

SEQLEN = 30
BATCHSIZE = 20
ALPHABETSIZE = txt.ALPHASIZE
INTERNALSIZE = 128
NLAYERS = 3


keep_prob = 0.8    # some dropout


# Load Shakespeare Data
shakedir = "shakespeare/*.txt"
codetext, valitext, bookranges = txt.read_data_files(shakedir, validation=True)

# display some stats on the data
epoch_size = len(codetext) // (BATCHSIZE * SEQLEN)
txt.print_data_stats(len(codetext), len(valitext), epoch_size)

# DEFINE PLACEHOLDERS
keep_prob_placeholder = tf.placeholder(tf.float32, name='keep_prob')  # dropout parameter
batchsize = tf.placeholder(tf.int32, name='batchsize')


# inputs
X = tf.placeholder(tf.uint8, [None, None], name='X')    # [ BATCHSIZE, SEQLEN ]
Xo = tf.one_hot(X, ALPHABETSIZE, 1.0, 0.0)                 # [ BATCHSIZE, SEQLEN, ALPHASIZE ]

# expected outputs = same sequence shifted by 1 since we are trying to predict the next character
Y_ = tf.placeholder(tf.uint8, [None, None], name='Y_')  # [ BATCHSIZE, SEQLEN ]
Yo_ = tf.one_hot(Y_, ALPHABETSIZE, 1.0, 0.0)               # [ BATCHSIZE, SEQLEN, ALPHASIZE ]

# input state
Hin = tf.placeholder(tf.float32, [None, INTERNALSIZE*NLAYERS], name='Hin')  # [ BATCHSIZE, INTERNALSIZE * NLAYERS]

# using NLAYERS layers of GRU cells, unrolled SEQLEN=30 times
# dynamic_rnn infers SEQLEN from the size of the inputs Xo

cells = [rnn.GRUCell(INTERNALSIZE) for _ in range(NLAYERS)]

# "naive dropout" implementation
dropcells = [rnn.DropoutWrapper(cell,input_keep_prob=keep_prob_placeholder) for cell in cells]
multicell = rnn.MultiRNNCell(dropcells, state_is_tuple=False)
multicell = rnn.DropoutWrapper(multicell, output_keep_prob=keep_prob_placeholder)  # dropout for the softmax layer

Yr, H = tf.nn.dynamic_rnn(multicell, Xo, dtype=tf.float32, initial_state=Hin)
# Yr: [ BATCHSIZE, SEQLEN, INTERNALSIZE ]
# H:  [ BATCHSIZE, INTERNALSIZE*NLAYERS ] # this is the last state in the sequence


# Softmax layer implementation:
# Flatten the first two dimension of the output [ BATCHSIZE, SEQLEN, ALPHASIZE ] => [ BATCHSIZE x SEQLEN, ALPHASIZE ]
# then apply softmax layer. This way, the weights and biases are shared across unrolled time steps.

W = tf.Variable(tf.random_normal([INTERNALSIZE, ALPHABETSIZE]))
B = tf.Variable(tf.random_normal([ALPHABETSIZE]))

Yflat = tf.reshape(Yr, [-1, INTERNALSIZE])    # [ BATCHSIZE x SEQLEN, INTERNALSIZE ]
Ylogits = tf.matmul(Yflat, W) + B     # [ BATCHSIZE x SEQLEN, ALPHASIZE ]

Yflat_ = tf.reshape(Yo_, [-1, ALPHABETSIZE])     # [ BATCHSIZE x SEQLEN, ALPHASIZE ]

loss = tf.nn.softmax_cross_entropy_with_logits(logits=Ylogits, labels=Yflat_)  # [ BATCHSIZE x SEQLEN ]
loss = tf.reshape(loss, [batchsize, -1])      # [ BATCHSIZE, SEQLEN ]

Yo = tf.nn.softmax(Ylogits, name='Yo')        # [ BATCHSIZE x SEQLEN, ALPHASIZE ]
Y = tf.argmax(Yo, 1)                          # [ BATCHSIZE x SEQLEN ]
Y = tf.reshape(Y, [batchsize, -1], name="Y")  # [ BATCHSIZE, SEQLEN ]

train_step = tf.train.AdamOptimizer(0.001).minimize(loss)

# stats for display
seqloss = tf.reduce_mean(loss, 1)
batchloss = tf.reduce_mean(seqloss)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y_, tf.cast(Y, tf.uint8)), tf.float32))

# for display: init the progress bar
DISPLAY_FREQ = 50
_50_BATCHES = DISPLAY_FREQ * BATCHSIZE * SEQLEN
progress = txt.Progress(DISPLAY_FREQ, size=111+2, msg="Training on next "+str(DISPLAY_FREQ)+" batches")

# init
istate = np.zeros([BATCHSIZE, INTERNALSIZE*NLAYERS])  # initial zero input state
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
step = 0

# training loop
for x, y_, epoch in txt.rnn_minibatch_sequencer(codetext, BATCHSIZE, SEQLEN, nb_epochs=2):

    # train on one minibatch
    feed_dict = {X: x, Y_: y_, Hin: istate, keep_prob_placeholder: keep_prob, batchsize: BATCHSIZE}
    _, y, ostate = sess.run([train_step, Y, H], feed_dict=feed_dict)

    # display a short text generated with the current weights and biases (every 150 batches)
    if step // 3 % _50_BATCHES == 0:
        print()
        print("Generating some random text...")
        
        ry = np.array([[txt.convert_from_alphabet(ord("K"))]])
        rh = np.zeros([1, INTERNALSIZE * NLAYERS])

        for k in range(1000):
            ryo, rh = sess.run([Yo, H], feed_dict={X: ry, keep_prob_placeholder: 1.0, Hin: rh, batchsize: 1})
            rc = txt.sample_from_probabilities(ryo, topn=10 if epoch <= 1 else 2)
            sys.stdout.write(chr(txt.convert_to_alphabet(rc)))
            ry = np.array([[rc]])

        print()
        print("FINISHED GENERATING RANDOM TEXT")
        print()

    # display progress bar
    progress.step(reset=step % _50_BATCHES == 0)

    # loop state around
    istate = ostate
    step += BATCHSIZE * SEQLEN
    
print()
print("-----FINISHED TRAINING-----")
# Out:
# Loading file shakespeare/merchantofvenice.txt
# Loading file shakespeare/loverscomplaint.txt
# Loading file shakespeare/othello.txt
# Loading file shakespeare/hamlet.txt
# Loading file shakespeare/kingjohn.txt
# Loading file shakespeare/various.txt
# Loading file shakespeare/sonnets.txt
# Loading file shakespeare/asyoulikeit.txt
# Loading file shakespeare/titusandronicus.txt
# Loading file shakespeare/2kinghenryvi.txt
# Training text size is 0.9178218841552734MB with 149.2587890625KB set aside for validation. There will be 1604 batches per epoch
#
# Generating some random text...
# $G'ddq[^.$'R[G.$qqq' qGO$ G^q$$RR.R<G.yOROqqRG.q$G.RGG$y$^  '$y<q$.R$$.^R'<.^^q<B.R.^B^^ q^^ ^OB$^^qq$B^qy#<O+qO^++$$^qqO<^O^^#.#R^OR^^^RRR^^ R^OR BZqB$qO^Rqq^q<OB+$q+^RqRRG<^O+<O<GO<.^^.Gddq.^d[^dRy.'yh^^y y^ ^OOB$#BB+qOR< +dqq+$G.<G.R. R qqG'MR RR$<<O^M M$yq^..Oq.yR$.$.R^^GBq^$h $RBy^^R$$q BqGR$ R<Gyy^$^ B^^qqBqBR+BB#^^RO,O^O++^$OR
#
# O^+qRO$^R.O$dG.f$..G .d.$dRR^GRR.G.y^  y  yq Rq < yqO <qy<BB+<Ry<<qR.Gq^$ qR .. <$^<<.$^y..q..A..<R..q<.qqGo$GARq$y^R.^$^qR.OoGyR^^RO.yG^ROy^R.^G GGqOqRB^ROG^$^$$^G$'$Oy^+OO<.^^.<$[R^qGqd^^R ^G$$.y^yq$R$$q<Oh^$<qqR#RG$<Gq<^GG.RRMR'RR^.<'$^.^.G<y<q8^Rq$$RR^B<yB<q$^.RGq.$ q$yyR$OO.qqRBqRRRORGqqqB^OG$RO$GRRG<.$yqyRRM<$. $G  R'G^^$q. $yRR.Bqq<OB<<^qqGR$<^.+R.^.qOO.^qG^GORqRRR$$h$.q.^q<<q$R.yo$$.$R+.^<hGh<8  q.<^R$^RG^B$$y^ <.^R.q ^ $yyRq<^<B. Oq.yGqG$y yGq.GqR$$q ^OOGG<+$OO^.<dR^<G<.d'G.[[qdGd[^h[^ RdR O^ BOBq q^^  +OROq<ORdOqy$.q$d.G $q^q Rh ..q^RBo $q^BR$B<qq$$qy^<O^R.
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# q.GdG[RGOO	OO	 hdr aie  in  hltnta edantdtntsnoit os ae   ste onlttdeo
# t oaeei s  ole ao d  o la  enet nos  thah e n hohser
#
# A	TAtthiett    ot hiloo  tt roa h eato nn tn nt  tlee te  le aosst  toheah thrnt ehts eshthsehhn ot hlsele ns eetnr   een neto et
# t   eietno
#   ohh r r se notshirniees  aota a r r ehnned tt e osor or nne e oea  nrreno h ei  or eet hehrehe
# ntaso eeas  n  oe nte e oerdo   ni eoeeneosn enos dsro soeo
#   hhhole ah  nrnho eeto otienrsa
#
# 			 aa tnl  ii hrh nen heh do hoose n
# ond ihhd sei hs  eel l iost   aaao
# hn
# n hh  r iesenr  atdt iar tsna oense o eee n tae e  lehso o  ne to e lsooeeh
# onth ohe   hee      hl hds l    elrolnt o
#
#
# tthet heott noonohs nteih oh saoo  notonn esre  etestors t
# i
# 	et tstieohttaoeh teah e a  tsehe
#   ao  eao eoe
# rd	tdro shesh tso ehto  s le einone   n e ie r  e  oor heeho
# 	e	o srr ate i ee aed
# d
# o Aoohere ras ar nit en  eo onehtn en eaesehs toe hnetrtt
# o
# h 	Tah thi soe   r ae oeos  donor dheoot
#  	nrtres lon irn  li t hh h oees e a  he eoto e e
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# RqMOqA^GOO	Ads wote  arte ott as wler ian tyeuss son the te tas aor whes taott warlte
#
# 	Tnthersh eethtsedd  hou toor hossse to h thor oidteh oaned toen  werre oor hn sithee ood wathee htheutihte wto tehs ee  har  a ol ts a  hte ths tha did aans ots tsees ar toer etaerd.
# 	othh hrie hio tttt e tr tee  ait.
#
# ISSIS	has t o ute out s ao thts haed
# 	ai hhsatithtsasor ae e tah lsso alo est enr har oes asrette
#
# 	Oasd  euud w thty whest hle s ta ise wtthetou eriits won th eo  ter eat t hield oetse,	so hs hi lont he ons
#  Tearsett er tte eoued taae whss eral t hhsts the th ote oot tothihest.
#
# HAo I aer its tahl atiroeu ehits aal to ster
#  as  wou t ouu sithte  htha in hhsr es the edet sthe attedd
#
# TE tet otshothe h ol ot to the th ilot tio oo  ie etis e ol het tout. teer tha aenssto usls oen hes had btta as
# 	tor  hhotetaee dhhond hor sttes ots hts iits tite sou, thee orst eid,
#
# 	oroteet oeu letttt hoe sht s had tes s  oie
#
# 	to  otes  e arsar s hotsi is than er sthsi ot ha ou te aon too to h or os t
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# $ AR ORSAENNS	ANdnierting sof hith ing o an ilg enaroe are aso sere ist e e ad ter ouree.,
# 	The saragsaen fith so solet ron ens
# 	iche aor toures fy as toe mrer,:	Iow he thel ofe rorustereens ale sin dr serrste tertil ns tt he  fists ene in he tr met, bou ee llete, and ind ter.
#
# LOANLOONC	AAn theere file le so sot,
#
# 	Ad nddout eroug atis lor one bene
# 	orse inodet irt inge coude niot ine,d, aor ofeset onrtt ae it igat, a tiore her solt oul t rotere hu de rit,.
#
# TASESST	Itand weared.
# 	OEI	Sode to tho  ha sse oost hi tero o thamerss srrtest
#  oud wlalins are
#
# TEToent tha h tardseagondid sis, arent orad, and the that, so de menat tither
# 	Oedr ton ite af to he ro ds sol ty ou ind the mos thal dene it  he sreer tordoseera d surotto ad fuer ti he th andes ie sinetr ineg sent mil di ond os ter as sat rete han st e arer, ad ateire is mandis.
#
#
# ISAISIR	Alotd mean yoros and, aneer yaond,
# TAEd Asrin, bout
# 	Irritee fatois taent
#
# SETOALAI	I w ther tiser, Is, in de sat  ind oule
# 	af asrs he co lesthenr
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
#  Go doofras dond bat ot or tiledsoforr o de bime
# 	O me mit teeen w nt ng hetronesat netoenearit.
#
# AMEMTAN		I withind what osser an a n th n antonon sualid tord meedesrow bing, for mhiss ofesterie anerens in fill cy tim bou t nos tor ariboered te thin mastaall
# 	Ankod mas no hinot heee an soulan,; wavy sho dess bold ou, tong
# 	nat tuald hof moses al  afee mithorg ne the nort, be thin bralasdent oou ham thas maves t ne sat, bint ond the e tair,
# 	Then bithenim is thelant heamedaer soe wot ml seere
# 	not it enther nut ot ir.
#
# IE I an there b ton, worens ther
# 	an fhot har won sout ant nowinge nde mes, bod sa teralad maceninedite ous a meader thean, thivh shet, wirinow it shenderin nos aneseranes malasdt
#
# IOARONONT	I i an he lee toreradas oftom ther snoton thirim mend ale than theee, ank
#
# HAMRRENI	were noundesit eule chith tinteramim of ro seore thy us
# Torethil  aelave wimom ood nins her hin ther
# 	Ond nteram hans misee, what nowetest oun bn huar sontofe nof is hareer
#
# 	Whers th to teas to mate
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# dqu asesot de te thar atis ta ty s as  a ceroted nowras hase sh a her sissalo bomy
# 	Thicth, and efaad you heng chound steer sanerdethe anging s eftome fees houe suns ase an ad ea nay ultald, bolly ary sureea no he at ome
# 	of hee h of ant of has inoulous ond coran,
# HALThis me het of hor a ees a  ou sartitely on.
# He Iwer for ers m thee, of youl han son ba bith thate, sir thin gaat,
# 	hitit tre shast asdito hand woen o thy loull, wit outhane too hand theeds.
# HisO Thus ictutt of the a soe cearl no siro feithad oo thon iess,
# 	Thes han an en harrs shal h fhee thowr so lontt it a and th om or her, bind ha thras, lfedstho  al as orane seeade
# 	A whou dontotade fart eri n chum fast antathe cotert iser,
# 	I thars eae dall of eal the  tonthad wares heren with fo eeros oree, ca mang tos, a t enselsoso ou duce bas,
# 	And ar anlall co bronos he and, thit and thtu an ho tiss lato het.
# 	Huen fat er an tolo ound asod attan torthins
# 	of the to me hr tou ceelede, chotr ment to ture, at yur af thore
#  hel ha
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# Gh,G	RI tast he bons ham toe hiseen the ser ie boshator the, borero her beicusting;
# 	O thinititeer by foe my thes hes, with theamese t tee entins blese,
# 	She ae and hine il hive to thatith wend thare to mound of mestren thy,
# 	Oo hy lith with as the hart, has sund, or of in thon whes wilt bet ous and theith al musend wilg whe heed
# 	Bith my serr shen an  on with for is mach men,
#
# AE I Ancured than therd, whe sis in fur thath ar int thit no me
# 	Why ng nt hreaceanengore, ads forls
# 	foutthesr serin tre mad ang an an theer
#
# 	Whut sh ml woul dr wer,
# 	Whi nust sare tor, tho  hat ar so nes, and
# 	To e wend hond th w andele, ing fo heastor thee wooth of here,
# 	So that ha siol  its ilt,
# 	Then ae d ar outter thar herims min this hasds, senit heantigs afe theineeasen to theae hars saise st fer the siten frameesee, in soncous thal anl hat beneinill tat hof angtry me thees hyed the threne fur the wendt fouh at elas ond biteres, and but,
# 	And'ld shof is foos. Thar beatrot and thet malost
# 	And want thet
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# ROGANLOR	O, you a dishels, whe is ly'd. wheraim soulone siel, must thit thy bendase,
# 	I mothe t ris his.  on and owte ow thong traly morl bat andelome bnesste siotesser my the tire.
#
# Hon'd shou hain ats br will ca mron tee tor, willess mave wing the meeller.
# 	Antimon t am no saig, ar a less welide all ofse ice ty af lod had weater
# S I wo thing mate trrut in basis or matteer asel, him malie in on
#  tin esturess thy all the pill you,
# 	I all ath hull ard sime son
# 	Bome, hav, nots as sipseange mlove tithe appecaren sirt ne ty thon, whin wisedert, and to hee me litt tout be anisen,
# 	his my handels halke in tey to herid, have ortthere misitiseleas,
#
# A tile that of esid,
# 	Is hame, bly of ter, my, ar ale of museach,
# 	To i tit meren tis hat ig st eed om my thertis
# 	ala hige, is the walled howhe saatenthant to puntses
#
# ACO	I thare whe bor ontseacie the whim on ongaen, sow
# 	A mlall wers fom a ler or wortith manerede
# There on thes bing ateder it wale somy ane, yatilores,
# AA	Do bot the bint sore ane
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# .R
# ALIOUU		Ardis is or sitlor whou horesiore, ferite
# 	The loth theanore, bry in to tis soos, trous a mon whin omtere tho gaed ef that of rrss ofe ore, and wtre sof of the wisttane on ad ming to sol ire tre clanicaminong mo the ar deilss fers, whoth to tit me reamersot so talit wericinom ofstoon ow is womd me min sth a der to st lurknd ast ous.
#
# I USalen tha houll hom it the mer shice sels ttald the anghelow most tre suel, ant he ris mere tal  the tole, whavy tha  a welase feach ots ar the a in tre, more selarours
# 	Wis,
# 	Thou with that worl se mele all itele wome mull thee arle the, torl the or melrend otraine,
# 	Thy saith seas wers thes thethe mo chou witlthad, wht coomist inteas il tis ithe
# 	far mrine werl, that thy fores witt a saiss on, an will move to wirt, a domtrite
# 	Toud silont of toess lede wougts entres marth thurer thills sf this and the so etine wouds hove sters sher to mire sonl horead me hite that will tar him fars hit mend alal derin,
# 	I waled
# 	Of my seavos so nou the time
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
#  hARR	No, srat,	And ing,s the asener in ber wher all sto thes his atrus see oure hour thet in me these
# 	I wichars shavu hore ie as thes and are are on mo asels
# 	And tat e sperese chateessalators,
# 	To eestelad all onen in musd bent sanien ome the eftarlare, hive more my tore o ssangor,
# Lof i hrid ter hing tomen bean nes a bees, thor my sins losss;
# 	Hor tas seose toul hass a derind tyas.
#
# AEnTE
# 	The sorle a soud trets, meshoutteshir of hount ty suide the trend, whe sareed hat the e ong, dound mes,
# 	In thos ade tosessatriog try or halss mers andine.
# 	Ore sore soon aricor ou te t nere tir til so lank,
# 	Ther wilg hout be he his mord ound nowradnd
#  I ald word and wy lowess, wae tee the erich of tare ond
# 	In mond no re ter nath ne tore il her hat tondes
# 	I whar astere senst oredstored sured nigr hack;	And andyofertrerind astae,
# 	The eamae nes and benge his and hich: I held
#
# TIMATII	Wo as, the sape ein is:	Theu wlut, ard ble to teee,
# 	It ow he doss earet not mant e efreres amy hirsse anleress
#
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# y sho woud shane bruther ase for day se the wate: wher, ing mis. It it leid, im it te pestrinoung heen old of his; and;
# 	Thenom thu garan hil selave hy brosh suros wee tan and mus, the suat, hy plancus to thou wrass to sion.
#
# 	[End nits]
#
# HRASIIA	Afliod ho the mak and to dig housdinn
# 	AT thim home thou henditee the cuntee om.
#
# LIA I ham seacoso nownd an mree fencins shy dorarse solt,
# 	Arayingous omtr ouc ooustale,,
# 	Fowesth thouersounth how thin wie doud or han seaves
# 	Tours werets, has mose. To mad eento alo sow and ang
# Thandshase, I how of thy welestr not thurt asss curs, de wen love say sime. 	That that ing hous has hat,-	To doder, mene of the winether thar ale off
#
# ARTSII	O adyeders mlake has tood marnt whee hood hid allse fouses wucl have
# 	And, him nyt ro the wore int thou how aline,		As alethonto the coustorg.
#
# 	HeLou houd tar is core, anceran ano esens, choustrst, a d dn why hungo do ner cirs an thoush toull
# 	Or sintitt are that.
#
# 	En hhe weer marethali net thises of t us and
#
#
#
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
#
# AG TOANNO	O as seee thar wonh murd't wy llede this sand as te thour that I with a pranise in tree
# 	A sill of i thee wo broon ter mast on thould with ter whot,
# 	Fron wel thee her, shat a mosiet
# 	I waver that and hasd sare on, that batt, and sun stared,
#
# Atd I sain ho dot, the take
# 	Thou shy mu had and bas to mesice do and, I a dame a somas, in. 	O whan e rashas, I dusinort,
# 	O  the sing our well tis alle ountile beanchous.
# 	And strict, worture a mondrong tou muld atasuloor thys,
#
# Ar ift as wilt.
#
# OTIENO and thy fallsime,
# And my theato bat teintaros and my:
# 	In homer storeerte ind as to ladeer,
# 	And, werigood has mad yau be ard to endes my my tais of thougit
#
# COnS O I I  a my layd;
# 	I will o fou the thour and not,	Is listinod trike, would af srunt inted and,	Shate, my messes me lave hat out ang ave hell be thou at hir, and badigount old wer
#
# 	[not in thaus why tlanghth ou tion
# 	Thers seme ho lath, asd bist ind
# 	So murci onto so mat yal and tometter ing oud strer,
# 	With lanserd has bear
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# y
#   If Gild I hues ner mithis,
# 	As mle thou solitit why fars of fosculof
# 	ost conteising,
# 	And an ham that wothore tele
# 	Ance is ounca por in thore the coll thy sepint
#
# 	B wo to tat ere math of rof lotes and saye
# 	I mave ic wnth sow hat the leskill,
#
# AMEA	Suchilaid your mand in woresthay to shad of rite oo hat sely, these wouth yous, bu hemtern of lord therthor hore,
# 	Old not in it the wrathen hile af arester
# Teor, it her im the line ow my those in ond rere thin till whoth
# 	That till ape on to ture't
#
# 	I his ling best tith tn s ot the fouter.
# 	Bet to loule tue an his than of mis wher of ous
# 	the tos hell spall fult, to bly fo ter feier
# 	I mot theie, ard werr t thin sier wowh oncoul it wirthar.
#
# 	Hirge as wer thy horchare ans of tite
# 	O mr nocliss it the sturt as.
# 	Hat enolet this others pore thou thoots ties
#
# 	Sheenitariegarom ar an ou thes.
#
# LERETAMCONA I wish, by thoue wore te of to how minstend
# 	Ay that inteis mlerad now of
# 	As my the cillon. But houd th sis
#  ARI I that of to tlou o
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# oRo dither shrat thes woud me, and io on den hhe prtore.
#
# RARDIO	O wasdears dod dre fored to same this
# 	I shald the to mess, whit semse,
# 	And an dhis shrl ase fo les man ame,
# 	ow har, wread ngtss, and on mete all bol ale
# 	hat the ale hid,.
# Whace me in ent mate ondees my looe.
#
# 	[Exee t a litieg, wight.
#
# DERDESI	By sras, wret then wenther weld onerd fice,
# 	Thil, thas and orind asshay to wente faten stace what bettsers
# 	thou detes all.
# 	Her eng to be stherean ad hy wish der mons,
# 	Whou daer hou mage insired.
# 	Wuthet in me ser he the shatess and tond how onese
#
# ToRA cooes the ase ham a dudttrase that me his tings, 	Ant lom mite, this woncosof mes,
# 	and tustr nst had waill his of and so to dess woutt,
# 	Shandead a this to so all shan end what deald bate areniet som,
# 	add wimoll sin e hat what im her wight iesor
# 	There srathhe daint tes this saras
# 	to these hese sese mirgons,
# 	And monce se angint moscelairs,
# 	of and coreto to me hidedirs lot athing, to me stes in the thank, 	I tam ntt th the
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# G', thy affad ard
#
# 	His to he thimk ent thete samoun. he mon sanow
# 	Betrter wathen soued hear hess
# 	Thoulinit, a lirt ong tay the tet the bentile in.
# 	The fir the sestore with it spell come in hine; hald; I hosh in borats so me here feelthan tir cave the the pit beact.
# 	I to live in spure inss the and are, whe wath, in, at how sun a dsunce.
# 	Whe enels and ani in at trly woth m you most; mer in wnth, hit, bore
#
# RTIASDONALIUN	                                                                                                            his wall fou alid in aseded
# 	Te priokso wet thin that oun the and
#
# 	Inther with aroshe thongry saligh lave; I pale a my. theue
# 	And arowet him hat aral ardeathe thighteach as inghintto mast
#  The firte,
# 	I feledong forestroughtramirese,
# 	At sound far is ans the be then mo thy and my bant a liken.
#
# 	[Exetn and sestry willes not his word.
#
# TUSNLARDND	Cans, mose arll ow
#
# 	[Entereth of for with i firled, what whald teat
# 	is wish t an soun bureas
# 	And is is marttel
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
#   the simore sore,
# 	hes to suns lare.
# 	Dy to mord on tretiree mich and?
#
# And I hear theare is tom sonthimsso
#
# 	Andospothearost of tas men
#
# Anding and will, of you, mereed tim eacsino, and you hour thou
# 	so his t to sorl bot, welt or spill.
#
# I So a onterss,
# 	To so morto mish of those of in bas efol him ala
# 	To the herse her butiot tand
# 	Int ie sen dow sous in why lide.
# 	To thin herts, or meer tyem fis leads,
# 	And now and in thishelf then aron,
# 	Inf ther werte and one shane to thay,
# 	And oof the sint dame find tho shere to ming,
# 	O lond that an hoverind a hou itean the salleans with to this,?
#
# TAMON	Thealanoth moue trom mile ow my let bidds dans ast,
# 	What so thes if thin,
# 	of aterather misetair on so shir ands my sure
# 	shou hirhind tomhim birt
# 	it the deare of the hood wand ho tond ovens
# 	Tit hit sae in to saly sar trentoul farland
# 	the hears so do mrot out thow bue
# 	aroth hemonearon my sood seelt
# 	have ay that hom ald bo tharl her deass
# 	And be andeat ho dest then aye thele wath,
# 	of t
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# es, wall you
#  tuet to so hath a thim iose the thilt.
# 	In hir and and the and in her
# 	Alad in thim o thee what bo nos to chateres, le dill do my thou held,
# 	Will she to to pulch arst af thee: a d whide with mintond
# 	That if spe clon to thou ty be tes, ane shis hy his, wield his wond,
# 	Iwere our wit than madr he warst our, hour if and.
#
# LIKIO	Shat the and on with ar tay mich tie dean
# 	Thy hinbolt thourso tim suren lodk, thour, me tele bigrd.
#
# DOKE FOCINIO	I well,
# 	To this mansoo eet hend bad an, we hands thound;
# 	In the eant hin love out are sorle of whel. The hall, sherle in thime.
# 	Haw t ent tite anteeditirs be deavise ont that an aroon of hean;,
# 	Noth me willome tise our a minee father.
# SAEREN	Erellt of amy like werles. HAdRowithou tho  shet beon are these arond hhare wall'd paisee, love you
# 	ape the foredemor thind,
# Apparthee hreal the firresay hhells and heriend bed and and poss,,
# Find werl that suce will's. wrold wead, bo nestorghondense muly
# 	Thal wall, his histst thar asdand
# 	Tit
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# y'd tintuls
# 	to drest hes my ater his toeca stle sills. In wall so tore ort wo have bay wer soot,
# Wat my sprat aldicint art than mere.
#
# 	I Sil ous ank apen tim th ing of mors
# 	theer stlect, if for your thentorate
# 	That the bose atiand it bese.
# 	Betore tull bet wound his, an  ne sounde is farlest fous
# 	a teatem not ar then sor well,
# To monds, but shad thend swe tlet is truge and munt af mit to say chen helf fang would tomth
# 	T wis somelt men sred
#
# RUCE LERONO	I have son thing.
# And tincy. O whosd by sat woon what.
#
# HORTANO	Cas I,
# 	That yout troth shear dide at that is yet thou arign you to th all
# 	Sen it, st ins he mut woth lott a shall, ay teris deist were,
# 	And sears.
#
# ATSENIO	A, theth he blat when hen, hich,tass felt my lead.
# 	At hart,'to te would sorst llt.
# Thes it, sir wand it'mis all in, wo ter have ou thee oned my theate
# And the mudnd a tomam nesse toor.
#
# AORONI	I wat thou a drald aft tete tor wers
# 	The hich high this is the mornend
# 	And wiml a mo mes heventertond thoue seet ins,
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# oRone ous his song, that celfater.
# 	Mas imayousedante brome shoul four dading,
# 	Mire, thy bongous wat of amise ay spack andedee thee
# 	The hipl be se calie sen, be if thy pared wond chace beee in hers.
# Les the failest
#  of houd dlike and cones all the heil,
# Bus cyuctince of mestyt thou the sown hove:
# 	Hard thas bur, afe a pors.
#
# How alather whertemear on.
#
# LORD	And bre herpelfesty treye,, thal him.
# 	That we the thim to beat a comper inshood hen arst there betted:
# 	Then and ald somering, ane he serpente
# 	Whould somerte father fore.
#
# HAMLET	Bul her as walicairg ay hipp
# 	And wo me thars, horeshele thot hoot so ar an this the wsact:
# In my lond widh a ang fore hone firnend?
# 	Tam shill so ther sherss they, in stlowese, a darinttela
# 	I drll ang the his thace have, and that core yout her foth as arany;
# Ang hem orame tuman hom ane a cooes ont yot what to thee hom o the hen,
# 	What weacs.
#
# THUROThack hime issone, I hall theurselall:
# 	But nothaty tha keed.
#
# ORANIL	If hom many hand he firnore and him
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# , hhoso, swend str is with bight stavis.
# 	And beatt a st bug fielition
# Whe paven shosleear wo flond har sume we to harted the bad d dights heals;
# Thomewer ow oriof, I moreshin. Hhar the hees not.
#
# 	And not wise ans the ame tond.
#
# 	[Exeurt]
#
#
#
#
#
# GICNAT	To I fould ty swrecter ove in, the shat a wanleng bits tell?
# 	He meathour the treeang sintice is she werlors the withssard wo lord
# 	Terisonaty have not her berour ow, and ho trees.
#
# ATRNIC	Inding mand the weid,:
# What so by thy with andstints the mincolosous,-tossind thear insealilive the
# 	thirsitids widl be a wret
# And ditllse than buts tere.
# Lout, whinings an wercontory of the siel ic mue,
# What selther must beed of thy arae of her sith
# 	hisstys if that touls heakersers hut;
# 	ning'd sart. Take to thought is not.
#
# OTHELLO	I
#                                                                                                               S CERIIIC
#
#
# CANCIIIS
#
# Cake you touts me stam and who hadtin
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# y a fats art.
# OTHILO	I shill to thi dald weil stell beat hand,
#  his dompas tentole ane orthat
# 	The perones, tertee theepon hasse sould to th y sence, wliee
# 	the wornes. Mone tome nemse dade sis frerit as maice
#
# ACI I  a  no wier nought
# 	Ould what a dhent hir doth hour dostlee:
# 	F o
#                                                               Whit do me dust of sord
# 	Alior thou watls bar to des fer con and of cimeen:
# 	I wald so mat in bill the danting.
#
# 	[Exill, and with whe tas owst, make you,?	The sise ame wadentlond, in in widhine ithole, ings, wourd dor hant my soedes wond.
#
# 	And that hout in he at would a this bled, of maly
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# Generating some random text...
# e
# 	An sit you wher the siof hers be wo mat,
# 	Why thee a morter this be toumas to
# 	Me thet shy hantel hight he dine and hum is mut a serand be.
# 	TITUS ANDRONICUS	Why me thry astins: and sielou, sorar hos, be not be derse.
# 	That swell sous to not heave ary.
#
# MORA	Comoor trenen mich: tere moscerour deee
# 	And boon a mond of steld a dord on his him lice to sake to he
# A morin him hear it the mord thay come you? Mersoue,
# And wit ly tlou spait to brentert
# 	Wit  ou sterenow sores ou do the prey hore heve in thou come
# 	This date homy word the geirest, toowiof
# 	But, why to hha born me loods and love an  herin de my here
# 	Sich love, you bath t ou  that stare my leds.
#
# IAGO
# 	And had thas sire is this and his to seye
# 	Ar why tind a saie then a deats in and spoagtt
#
# 	It s to love ho now will spate is heave air sutuee
# 	Fom no lime it my stiln to therount, to share are as a doth
#
# 	And sol oree a llore, that him eetite sous thyse ald.
# 	The eres ther aranto thy lland:, And ala do in thy load;
# I an at aus
# FINISHED GENERATING RANDOM TEXT
#
#
# 0%                                        Training on next 50 batches                                        100%
# =================================================================================================================
# 0%                                        Training on next 50 batches                                        100%
# ==================
# -----FINISHED TRAINING-----
